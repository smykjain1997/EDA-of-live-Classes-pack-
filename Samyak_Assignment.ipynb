# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iu=pd.read_excel("C:\\Users\\b0\\Desktop\\Data_Analytics\\Different Data Sets\\Internshala\\stone2.xlsx",sheet_name="IU")
bu=pd.read_excel("C:\\Users\\b0\\Desktop\\Data_Analytics\\Different Data Sets\\Internshala\\stone2.xlsx",sheet_name="BU")
tr=pd.read_excel("C:\\Users\\b0\\Desktop\\Data_Analytics\\Different Data Sets\\Internshala\\stone2.xlsx",sheet_name="Trainer")
sb=pd.read_excel("C:\\Users\\b0\\Desktop\\Data_Analytics\\Different Data Sets\\Internshala\\stone2.xlsx",sheet_name="SB")

# %%
iu
# Out:
#      Child name         phone                    email_id  \
# 0      CH_30001  911100221000  s2m_test_20001@tests2m.com
# 1      CH_30002  911100221001  s2m_test_20002@tests2m.com
# 2      CH_30003  911100221002  s2m_test_20003@tests2m.com
# 3      CH_30004  911100221003  s2m_test_20004@tests2m.com
# 4      CH_30005  911100221004  s2m_test_20005@tests2m.com
# ...         ...           ...                         ...
# 1678   CH_31436  911100222440  s2m_test_21454@tests2m.com
# 1679   CH_31437  911100222441  s2m_test_21455@tests2m.com
# 1680   CH_30784  911100222442  s2m_test_21456@tests2m.com
# 1681   CH_31438  911100222443  s2m_test_21457@tests2m.com
# 1682   CH_31439  911100222444  s2m_test_21458@tests2m.com
#
#                               school    grade  \
# 0                   St.paul's school  Grade 2
# 1                K L E School haveri  Grade 4
# 2         Delhu Public School Howrah  Grade 2
# 3             Bharathi vidya bhavans  Grade 2
# ...

# %%
iu["Submitted At"].dtype
# Out:
# dtype('<M8[ns]')

# %%
iu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1683 entries, 0 to 1682
# Data columns (total 8 columns):
# Child name         1683 non-null object
# phone              1683 non-null int64
# email_id           1683 non-null object
# school             1683 non-null object
# grade              1683 non-null object
# batch_preferred    1683 non-null object
# source             1681 non-null object
# Submitted At       1683 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 105.3+ KB

# %%
iu.drop(columns=["batch_preferred"],inplace=True)

# %%
iu['Submitted date'] = pd.to_datetime(iu["Submitted At"]).dt.date  #'date' is a new columns in which the timestamp is reduced to date only
iu = iu.drop(['Submitted At'],axis=1)
iu.head()
# Out:
#   Child name         phone                    email_id  \
# 0   CH_30001  911100221000  s2m_test_20001@tests2m.com
# 1   CH_30002  911100221001  s2m_test_20002@tests2m.com
# 2   CH_30003  911100221002  s2m_test_20003@tests2m.com
# 3   CH_30004  911100221003  s2m_test_20004@tests2m.com
# 4   CH_30005  911100221004  s2m_test_20005@tests2m.com
#
#                            school    grade      source Submitted date
# 0                St.paul's school  Grade 2  lastchance     2020-04-16
# 1             K L E School haveri  Grade 4  lastchance     2020-04-16
# 2      Delhu Public School Howrah  Grade 2  lastchance     2020-04-16
# 3          Bharathi vidya bhavans  Grade 2  lastchance     2020-04-16
# 4  Army public school Delhi cantt  Grade 4  lastchance     2020-04-16

# %%
iu.rename(columns={"Child name":"Child Name"},inplace=True)
iu.head()
# Out:
#   Child Name         phone                    email_id  \
# 0   CH_30001  911100221000  s2m_test_20001@tests2m.com
# 1   CH_30002  911100221001  s2m_test_20002@tests2m.com
# 2   CH_30003  911100221002  s2m_test_20003@tests2m.com
# 3   CH_30004  911100221003  s2m_test_20004@tests2m.com
# 4   CH_30005  911100221004  s2m_test_20005@tests2m.com
#
#                            school    grade      source Submitted date
# 0                St.paul's school  Grade 2  lastchance     2020-04-16
# 1             K L E School haveri  Grade 4  lastchance     2020-04-16
# 2      Delhu Public School Howrah  Grade 2  lastchance     2020-04-16
# 3          Bharathi vidya bhavans  Grade 2  lastchance     2020-04-16
# 4  Army public school Delhi cantt  Grade 4  lastchance     2020-04-16

# %%
sns.countplot(iu["grade"])

# %%
a=iu[iu["source"]=="TEB5SMS"]

# %%
sns.countplot(a["grade"])

# %%
b=iu[iu["grade"]=="Grade 4"]

# %%
sns.countplot(y="source",data=b)

# %%
iu.drop(columns=["school"],inplace=True)

# %%
iu.head()
# Out:
#   Child Name         phone                    email_id    grade      source  \
# 0   CH_30001  911100221000  s2m_test_20001@tests2m.com  Grade 2  lastchance
# 1   CH_30002  911100221001  s2m_test_20002@tests2m.com  Grade 4  lastchance
# 2   CH_30003  911100221002  s2m_test_20003@tests2m.com  Grade 2  lastchance
# 3   CH_30004  911100221003  s2m_test_20004@tests2m.com  Grade 2  lastchance
# 4   CH_30005  911100221004  s2m_test_20005@tests2m.com  Grade 4  lastchance
#
#   Submitted date
# 0     2020-04-16
# 1     2020-04-16
# 2     2020-04-16
# 3     2020-04-16
# 4     2020-04-16

# %%
bu.head()
# Out:
#        Invitee UUID                                              Batch  \
# 0  AGIV7AYTBF4ZA6SA  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...
# 1  HAPQZDZXDJPMFZ73  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...
# 2  AHLT5B5XGJTONPE3  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...
# 3  HCNR5B2SFMSX727O  fREADom Trial - Grades 3, 4  [I] 11:15am - Thu...
# 4  BFIT2F3UDJ5MV5GT  fREADom Trial - Grades 3, 4  [I] 11:15am - Thu...
#
#   Enrolment Type Child Name    Grade                          School  \
# 0          Trial   CH_31440  Grade 2                             DPS
# 1          Trial   CH_31441  Grade 2                             DPS
# 2          Trial   CH_31442  Grade 2  City Montessori school lucknow
# 3          Trial   CH_31443  Grade 4             Reliance Foundation
# 4          Trial   CH_31444  Grade 3                             KRS
#
#           Phone                Parent Email     Opted Start Time  \
# ...

# %%
newbu=bu.drop(columns=["Invitee UUID","Grade","Phone","Parent Email","Opted Start Time","Opted Start Date","Facilitator UUID"],axis=1)

# %%
newbu.head()
# Out:
#                                                Batch Enrolment Type  \
# 0  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...          Trial
# 1  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...          Trial
# 2  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...          Trial
# 3  fREADom Trial - Grades 3, 4  [I] 11:15am - Thu...          Trial
# 4  fREADom Trial - Grades 3, 4  [I] 11:15am - Thu...          Trial
#
#   Child Name                          School Attendance
# 0   CH_31440                             DPS    Present
# 1   CH_31441                             DPS    Present
# 2   CH_31442  City Montessori school lucknow     Absent
# 3   CH_31443             Reliance Foundation     Absent
# 4   CH_31444                             KRS    Present

# %%
newbu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1711 entries, 0 to 1710
# Data columns (total 5 columns):
# Batch             1711 non-null object
# Enrolment Type    1711 non-null object
# Child Name        1711 non-null object
#  School           1694 non-null object
# Attendance        1592 non-null object
# dtypes: object(5)
# memory usage: 67.0+ KB

# %%
newbu["Child Name"].nunique()
# Out:
# 1446

# %%
newbu["Attendance"].unique()
# Out:
# array(['Present', 'Absent', 'Cancelled', nan, 'absent', 'present',
#        'Present with video and audio off', 'Attended', 'Attended ',
#        'Present ', 'Absent ', ':Present', 'Preset', 'Presnt', 'Duplicate',
#        'Present (Grade 8)', 'REPEAT NAME', 'Present logged in and out'],
#       dtype=object)

# %%
data=pd.merge(iu,newbu,how="inner",on="Child Name")

# %%
data.head()
# Out:
#   Child Name         phone                    email_id    grade      source  \
# 0   CH_30004  911100221003  s2m_test_20004@tests2m.com  Grade 2  lastchance
# 1   CH_30005  911100221004  s2m_test_20005@tests2m.com  Grade 4  lastchance
# 2   CH_30006  911100221005  s2m_test_20006@tests2m.com  Grade 1  lastchance
# 3   CH_30006  911100221005  s2m_test_20006@tests2m.com  Grade 1  lastchance
# 4   CH_30009  911100221008  s2m_test_20009@tests2m.com  Grade 4  lastchance
#
#   Submitted date                                              Batch  \
# 0     2020-04-16  fREADom Trial Class - Grades 1, 2 [I] 06:15pm ...
# 1     2020-04-16  fREADom Trial - Grades 3, 4  [I] 06:15pm - Fri...
# 2     2020-04-16  fREADom Trial Class - Grades 1, 2 [I] 04:00pm ...
# 3     2020-04-16  fREADom Trial Class - Grades 1, 2 [I] 11:15am ...
# 4     2020-04-16  fREADom Trial - Grades 3, 4  [I] 06:15pm - Fri...
#
#       Enrolment Type                 School Attendance
# ...

# %%
data["Batch"].to_list()
# Out:
# ['fREADom Trial Class - Grades 1, 2 [I] 06:15pm - Friday, April 17, 2020',
#  'fREADom Trial - Grades 3, 4  [I] 06:15pm - Friday, April 17, 2020',
#  'fREADom Trial Class - Grades 1, 2 [I] 04:00pm - Friday, April 17, 2020',
#  'fREADom Trial Class - Grades 1, 2 [I] 11:15am - Saturday, April 18, 2020',
#  'fREADom Trial - Grades 3, 4  [I] 06:15pm - Friday, April 17, 2020',
#  'fREADom Trial Class - Grades 1, 2 [I] 04:00pm - Saturday, April 25, 2020',
#  'fREADom Trial - Grades 1,2 [III] 11:45am - Sunday, April 26, 2020',
#  'fREADom Trial - Grades 3, 4  [I] 06:15pm - Friday, April 17, 2020',
#  'fREADom Trial Class - Grades 1, 2 [I] 04:00pm - Saturday, April 25, 2020',
#  'fREADom Trial - Grades 1,2 [III] 11:45am - Sunday, April 26, 2020',
#  'fREADom Trial Class - Grades 1, 2 [I] 06:00pm - Saturday, April 25, 2020',
#  'fREADom Trial - Grades 1,2 [II] 06:00pm - Sunday, April 26, 2020',
#  'fREADom Trial Class - Grades 1, 2 [I] 06:00pm - Saturday, April 25, 2020',
# ...

# %%
grade1=[]
for i in data["Batch"]:
    c=i.split("-")
    d=c[1].split(" [")
    grade1.append(d[0])

# %%
g=[]
n=[]
for i in grade1:
    e=i.split(" ")
    #print(len(e))
    d=e[1].rstrip("s")
    #print(d)
    f=e[2]
    #print(d,f)
    if len(e)>3:
        k=e[2]+e[3]
        n=(d+" "+k)
        g.append(n)
    else:
        n=(d+" "+f)
        g.append(n)

# %%
g
# Out:
# ['Grade 1,2',
#  'Grade 3,4',
#  'Grade 1,2',
#  'Grade 1,2',
#  'Grade 3,4',
#  'Grade 1,2',
#  'Grade 1,2',
#  'Grade 3,4',
#  'Grade 1,2',
#  'Grade 1,2',
#  'Grade 1,2',
#  'Grade 1,2',
#  'Grade 1,2',
#  'Grade 1,2',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 1,2',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 1,2',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 1,2',
#  'Grade 1,2',
#  'Grade 1,2',
#  'Grade 1,2',
#  'Grade 1,2',
#  'Grade 3,4',
#  'Grade 1,2',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 1,2',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 1,2',
#  'Grade 1,2',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 1,2',
#  'Grade 1,2',
#  'Grade 1,2',
#  'Grade 1,2',
#  'Grade 3,4',
#  'Grade 3,4',
#  'Grade 3,4',
# ...

# %%
g=pd.DataFrame(g)
g.rename(columns={0:"grade"},inplace=True)

# %%
g
# Out:
#           grade
# 0     Grade 1,2
# 1     Grade 3,4
# 2     Grade 1,2
# 3     Grade 1,2
# 4     Grade 3,4
# ...         ...
# 1632  Grade 3,4
# 1633  Grade 3,4
# 1634  Grade 3,4
# 1635  Grade 3,4
# 1636  Grade 1,2
#
# [1637 rows x 1 columns]

# %%
g["grade"].value_counts().plot(kind="bar",color="lightblue")

# %%
data["grade"]=g
data.drop(["grades"],axis=1,inplace=True)
data.drop(["Batch"],axis=1,inplace=True)

# %%
data.rename(columns={"grade":"Grade"},inplace=True)
data.head()
# Out:
#   Child Name         phone                    email_id      source  \
# 0   CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
# 1   CH_30005  911100221004  s2m_test_20005@tests2m.com  lastchance
# 2   CH_30006  911100221005  s2m_test_20006@tests2m.com  lastchance
# 3   CH_30006  911100221005  s2m_test_20006@tests2m.com  lastchance
# 4   CH_30009  911100221008  s2m_test_20009@tests2m.com  lastchance
#
#   Submitted date     Enrolment Type                 School Attendance  \
# 0     2020-04-16              Trial  Bhartiya Vidya Bhavan    Present
# 1     2020-04-16  Duplicate - Trial     Army Public School     absent
# 2     2020-04-16  Duplicate - Trial             Millennium     Absent
# 3     2020-04-16  Duplicate - Trial             Millennium        NaN
# 4     2020-04-16  Duplicate - Trial    Saint Paul's school    Present
#
#        Grade
# 0  Grade 1,2
# 1  Grade 3,4
# 2  Grade 1,2
# 3  Grade 1,2
# 4  Grade 3,4

# %%
data["grade"].value_counts().plot(kind="bar")

# %%
data["source"].value_counts().plot(kind="bar")

# %%
tr["Grade"]
# Out:
# 0       Grade 1,2
# 1      Grade 3,4
# 2       Grade 1,2
# 3      Grade 3,4
# 4      Grade 3,4
#           ...
# 169     Grade 3,4
# 170     Grade 1,2
# 171     Grade 3,4
# 172     Grade 1,2
# 173     Grade 1,2
# Name: Grade, Length: 174, dtype: object

# %%
tr
# Out:
#     Trainer Name               Date              Timing       Grade  \
# 0       FAC_5001  16 April Thursday  11.15 am - 12 noon   Grade 1,2
# 1       FAC_5002  16 April Thursday  11.15 am - 12 noon  Grade 3,4
# 2       FAC_5003  16 April Thursday  11.15 am - 12 noon   Grade 1,2
# 3       FAC_5006  16 April Thursday  11.15 am - 12 noon  Grade 3,4
# 4       FAC_5007  16 April Thursday        4:00-4:45 pm  Grade 3,4
# ..           ...                ...                 ...         ...
# 169     FAC_5009    27 April Monday  6.00 pm - 6.45 pm    Grade 3,4
# 170     FAC_5040    27 April Monday  6.00 pm - 6.45 pm    Grade 1,2
# 171     FAC_5038    27 April Monday  6.00 pm - 6.45 pm    Grade 3,4
# 172     FAC_5002    27 April Monday  6.00 pm - 6.45 pm    Grade 1,2
# 173     FAC_5022    27 April Monday  6.00 pm - 6.45 pm    Grade 1,2
#
#     Batch size   Batch count      Batch                  Topics
# 0         group          9.0    trial I     Rocking with rhymes
# ...

# %%
tr["Date"].nunique()
# Out:
# 12

# %%
tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 8 columns):
# Trainer Name    173 non-null object
# Date            174 non-null object
# Timing          174 non-null object
# Grade           174 non-null object
# Batch size      160 non-null object
# Batch count     159 non-null float64
# Batch           174 non-null object
# Topics          174 non-null object
# dtypes: float64(1), object(7)
# memory usage: 11.0+ KB

# %%
tr["Topics"].hist(xrot=90)

# %%
tr["Date"].hist(xrot=90)

# %%
data
# Out:
#      Child Name         phone                    email_id      source  \
# 0      CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
# 1      CH_30005  911100221004  s2m_test_20005@tests2m.com  lastchance
# 2      CH_30006  911100221005  s2m_test_20006@tests2m.com  lastchance
# 3      CH_30006  911100221005  s2m_test_20006@tests2m.com  lastchance
# 4      CH_30009  911100221008  s2m_test_20009@tests2m.com  lastchance
# ...         ...           ...                         ...         ...
# 1632   CH_31408  911100222414  s2m_test_21427@tests2m.com     b3rmsms
# 1633   CH_31409  911100222415  s2m_test_21428@tests2m.com     TEB4SMS
# 1634   CH_31411  911100222415  s2m_test_21428@tests2m.com     TEB4SMS
# 1635   CH_31412  911100222417  s2m_test_21430@tests2m.com     b3rmsms
# 1636   CH_31413  911100222418  s2m_test_21431@tests2m.com     TEB3SMS
#
#      Submitted date     Enrolment Type  \
# 0        2020-04-16              Trial
# 1        2020-04-16  Duplicate - Trial
# ...

# %%
tr
# Out:
#     Trainer Name               Date              Timing       Grade  \
# 0       FAC_5001  16 April Thursday  11.15 am - 12 noon   Grade 1,2
# 1       FAC_5002  16 April Thursday  11.15 am - 12 noon  Grade 3,4
# 2       FAC_5003  16 April Thursday  11.15 am - 12 noon   Grade 1,2
# 3       FAC_5006  16 April Thursday  11.15 am - 12 noon  Grade 3,4
# 4       FAC_5007  16 April Thursday        4:00-4:45 pm  Grade 3,4
# ..           ...                ...                 ...         ...
# 169     FAC_5009    27 April Monday  6.00 pm - 6.45 pm    Grade 3,4
# 170     FAC_5040    27 April Monday  6.00 pm - 6.45 pm    Grade 1,2
# 171     FAC_5038    27 April Monday  6.00 pm - 6.45 pm    Grade 3,4
# 172     FAC_5002    27 April Monday  6.00 pm - 6.45 pm    Grade 1,2
# 173     FAC_5022    27 April Monday  6.00 pm - 6.45 pm    Grade 1,2
#
#     Batch size   Batch count      Batch                  Topics
# 0         group          9.0    trial I     Rocking with rhymes
# ...

# %%
ndata=pd.merge(data,tr,how="inner",on="Grade")

# %%
ndata
# Out:
#        Child Name         phone                    email_id      source  \
# 0        CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
# 1        CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
# 2        CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
# 3        CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
# 4        CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
# ...           ...           ...                         ...         ...
# 106003   CH_31412  911100222417  s2m_test_21430@tests2m.com     b3rmsms
# 106004   CH_31412  911100222417  s2m_test_21430@tests2m.com     b3rmsms
# 106005   CH_31412  911100222417  s2m_test_21430@tests2m.com     b3rmsms
# 106006   CH_31412  911100222417  s2m_test_21430@tests2m.com     b3rmsms
# 106007   CH_31412  911100222417  s2m_test_21430@tests2m.com     b3rmsms
#
#        Submitted date Enrolment Type                 School Attendance  \
# ...

# %%
ndata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 106008 entries, 0 to 106007
# Data columns (total 16 columns):
# Child Name        106008 non-null object
# phone             106008 non-null int64
# email_id          106008 non-null object
# source            105876 non-null object
# Submitted date    106008 non-null object
# Enrolment Type    106008 non-null object
#  School           105084 non-null object
# Attendance        95712 non-null object
# Grade             106008 non-null object
# Trainer Name      105246 non-null object
# Date              106008 non-null object
# Timing            106008 non-null object
# Batch size        94549 non-null object
# Batch count       94549 non-null float64
# Batch             106008 non-null object
# Topics            106008 non-null object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 13.7+ MB

# %%
ndata.describe(include=object)
# Out:
#        Child Name                    email_id   source Submitted date  \
# count      106008                      106008   105876         106008
# unique       1040                        1099       22             12
# top      CH_31253  s2m_test_20999@tests2m.com  TEB5SMS     2020-04-22
# freq         1260                        1008    15636          23040
#
#        Enrolment Type               School Attendance      Grade Trainer Name  \
# count          106008               105084      95712     106008       105246
# unique              2                  823         15          2           42
# top             Trial  Delhi public school    Present  Grade 1,2     FAC_5009
# freq            87360                 3060      50292      64008         9596
#
#                      Date              Timing Batch size     Batch     Topics
# count              106008              106008       94549   106008     106008
# ...

# %%
ndata.drop_duplicates(inplace=True)

# %%
ndata.head()
# Out:
#   Child Name         phone                    email_id      source  \
# 0   CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
# 1   CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
# 2   CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
# 3   CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
# 4   CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
#
#   Submitted date Enrolment Type                 School Attendance      Grade  \
# 0     2020-04-16          Trial  Bhartiya Vidya Bhavan    Present  Grade 1,2
# 1     2020-04-16          Trial  Bhartiya Vidya Bhavan    Present  Grade 1,2
# 2     2020-04-16          Trial  Bhartiya Vidya Bhavan    Present  Grade 1,2
# 3     2020-04-16          Trial  Bhartiya Vidya Bhavan    Present  Grade 1,2
# 4     2020-04-16          Trial  Bhartiya Vidya Bhavan    Present  Grade 1,2
#
#   Trainer Name               Date              Timing Batch size   \
# ...

# %%
ndata["Topics"].value_counts().plot(kind="bar")

# %%
ndata["Batch"]=ndata["Batch"].str.upper()

# %%
ndata["Batch"].value_counts().plot(kind="bar")

# %%
ndata["Attendance"].value_counts().plot(kind="bar")

# %%
sb
# Out:
#     Child Name  Registered Number         Registered Email ID  \
# 0     CH_31846       9.111002e+11  s2m_test_21890@tests2m.com
# 1     CH_31847       9.111002e+11                         NaN
# 2     CH_31848       9.111002e+11  s2m_test_21891@tests2m.com
# 3     CH_31849       9.111002e+11  s2m_test_21440@tests2m.com
# 4     CH_31850       9.111002e+11  s2m_test_21892@tests2m.com
# ..         ...                ...                         ...
# 413   CH_32081       9.111002e+11  s2m_test_22161@tests2m.com
# 414   CH_32082       9.111002e+11  s2m_test_22162@tests2m.com
# 415   CH_31831       9.111002e+11  s2m_test_21876@tests2m.com
# 416   CH_32079       9.111002e+11  s2m_test_22158@tests2m.com
# 417   CH_32083       9.111002e+11  s2m_test_21404@tests2m.com
#
#                Payment date  Sale by Grade Pricing   Duration  \
# 0    16-03-2020 12:00:00 AM  SP_1001     2     199        0.5
# 1    16-03-2020 12:00:00 AM  SP_1002     4     199        0.5
# ...

# %%
sb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
# Child Name              340 non-null object
# Registered Number       414 non-null float64
# Registered Email ID     397 non-null object
# Payment date            418 non-null object
# Sale by                 258 non-null object
# Grade                   399 non-null object
# Pricing                 418 non-null object
# Duration                376 non-null object
# Sessions preferred      238 non-null object
# Live session details    217 non-null object
# dtypes: float64(1), object(9)
# memory usage: 32.8+ KB

# %%
sb["Duration"].unique()
# Out:
# array([0.5, 1, '4G+1I', '12G', 0.25, '10G+2I', '10G+2I + FAST',
#        '10 G + 2I', '4G + 2I', '4G + 1I + 1 year subscription', '10G+2i',
#        '4G+1i', '4G', '8G', nan, '9G', '10G', '11G', '5G', '12G + 1 year',
#        '13G', '6G  + 6 months', '10G + 1Counselling + 1 year', '14G',
#        '12G + 1 App', '13G+1 Yr Subs', '6G', '12 G + 1 yr app',
#        '12G + 1 Yr', '5G + 3 months', '4G + 6 month fREADom app',
#        '12G+1Year sub', '12G+1Fast+1Year sub', '12G+1 Yr', '13G + 1 Yr',
#        '12G + 1 yr', '12G + 1y', '13g', '5G + 3months app', '13G + 1 yr',
#        '3 months', '10G+1yr', '12G + 1 year subscription', 12,
#        '6 month subscription', '10G + 1 yr', 'REFERRAL 10G',
#        '10G+3 month', '14G+3 month', '6G+3months', '12G + 1y ',
#        '10G+1Individual 1:1', '12G+iyr', 'REFERRAL 12G + 1 yr',
#        '10G + 1Yr', '12G+ 1Yr', '8G + 1Yr', '12G + 1 FAST', '12G+ 1 Yr',
#        '10G + 1yr', '11G + 1 FAST + 1 YR', '12G+1yr', '8G+1Yr',
# ...

# %%
sb['Duration'].value_counts().sort_values(ascending=False)[:10]
# Out:
# 1             96
# 12G + 1 yr    26
# 12G + 1y      19
# 8G            18
# 12G           14
# 10G+2I        13
# 10G           13
# 12G + 1yr     12
# 6G            11
# 0.5           10
# Name: Duration, dtype: int64

# %%
sb[sb['Duration']=='12G + 1 yr'][['Duration','Pricing']]
# Out:
#        Duration Pricing
# 219  12G + 1 yr    1999
# 224  12G + 1 yr    1999
# 277  12G + 1 yr    1999
# 278  12G + 1 yr    1999
# 282  12G + 1 yr    1999
# 283  12G + 1 yr    1999
# 285  12G + 1 yr    1999
# 286  12G + 1 yr    1999
# 288  12G + 1 yr    1999
# 289  12G + 1 yr    1999
# 291  12G + 1 yr    1999
# 292  12G + 1 yr    1996
# 294  12G + 1 yr    1999
# 300  12G + 1 yr    1999
# 313  12G + 1 yr    1999
# 314  12G + 1 yr    1999
# 316  12G + 1 yr    1999
# 319  12G + 1 yr    1999
# 320  12G + 1 yr    1999
# 331  12G + 1 yr    1999
# 333  12G + 1 yr    1999
# 335  12G + 1 yr    1999
# 385  12G + 1 yr    1999
# 387  12G + 1 yr    1999
# 388  12G + 1 yr    1999
# 389  12G + 1 yr    1999

# %%
# Therefore the price on the basis of duration for 12G + 1y is Rs.1999. 
# So, we will be replacing the incorrect value now.

sb['Pricing'] = sb['Pricing'].replace({'95381 45678':1999})

# %%
sb['Pricing'] = sb['Pricing'].replace({'Multichild':500})

# %%
sb
# Out:
#     Child Name  Registered Number         Registered Email ID  \
# 0     CH_31846       9.111002e+11  s2m_test_21890@tests2m.com
# 1     CH_31847       9.111002e+11                         NaN
# 2     CH_31848       9.111002e+11  s2m_test_21891@tests2m.com
# 3     CH_31849       9.111002e+11  s2m_test_21440@tests2m.com
# 4     CH_31850       9.111002e+11  s2m_test_21892@tests2m.com
# ..         ...                ...                         ...
# 413   CH_32081       9.111002e+11  s2m_test_22161@tests2m.com
# 414   CH_32082       9.111002e+11  s2m_test_22162@tests2m.com
# 415   CH_31831       9.111002e+11  s2m_test_21876@tests2m.com
# 416   CH_32079       9.111002e+11  s2m_test_22158@tests2m.com
# 417   CH_32083       9.111002e+11  s2m_test_21404@tests2m.com
#
#                Payment date  Sale by Grade  Pricing   Duration  \
# 0    16-03-2020 12:00:00 AM  SP_1001     2      199        0.5
# 1    16-03-2020 12:00:00 AM  SP_1002     4      199        0.5
# ...

# %%
sb["Pricing"].value_counts().plot(kind='bar')

# %% [markdown]
# Take only greater than Rs 499

# %%
sub=sb.loc[sb["Pricing"]>499]

# %%
sub
# Out:
#     Child Name  Registered Number         Registered Email ID  \
# 12    CH_31858       9.111002e+11  s2m_test_21900@tests2m.com
# 15    CH_31860       9.111002e+11  s2m_test_21903@tests2m.com
# 23    CH_31868       9.111002e+11  s2m_test_21911@tests2m.com
# 27    CH_31872       9.111002e+11  s2m_test_21915@tests2m.com
# 31    CH_31876       9.111002e+11  s2m_test_21919@tests2m.com
# ..         ...                ...                         ...
# 413   CH_32081       9.111002e+11  s2m_test_22161@tests2m.com
# 414   CH_32082       9.111002e+11  s2m_test_22162@tests2m.com
# 415   CH_31831       9.111002e+11  s2m_test_21876@tests2m.com
# 416   CH_32079       9.111002e+11  s2m_test_22158@tests2m.com
# 417   CH_32083       9.111002e+11  s2m_test_21404@tests2m.com
#
#                Payment date  Sale by Grade  Pricing   Duration  \
# 12   18-03-2020 12:00:00 AM      NaN     2      999      4G+1I
# 15   18-03-2020 12:00:00 AM      NaN     4     1999        12G
# ...

# %%
print(sub["Child Name"].nunique())
print(sub["Registered Number"].nunique())
print(sub["Registered Email ID"].nunique())
# Out:
# 253
# 258
# 242

# %%
sns.countplot(sub["Grade"])

# %%
sub["Sale by"].describe()
# Out:
# count         255
# unique         14
# top       SP_1005
# freq           98
# Name: Sale by, dtype: object

# %%
sub["Sale by"].fillna("SP_1005",inplace=True)
# Out:
# C:\Users\b0\Anaconda3\lib\site-packages\pandas\core\generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
sub['Pay date'] = pd.to_datetime(sub["Payment date"]).dt.date  #'date' is a new columns in which the timestamp is reduced to date only
sub = sub.drop(['Payment date',"Sessions preferred","Live session details"],axis=1)
sub.head()
# Out:
# C:\Users\b0\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    Child Name  Registered Number         Registered Email ID  Sale by Grade  \
# 12   CH_31858       9.111002e+11  s2m_test_21900@tests2m.com  SP_1005     2
# 15   CH_31860       9.111002e+11  s2m_test_21903@tests2m.com  SP_1005     4
# 23   CH_31868       9.111002e+11  s2m_test_21911@tests2m.com  SP_1005     1
# 27   CH_31872       9.111002e+11  s2m_test_21915@tests2m.com  SP_1001     2
# 31   CH_31876       9.111002e+11  s2m_test_21919@tests2m.com  SP_1005     1
#
#     Pricing Duration    Pay date
# 12      999    4G+1I  2020-03-18
# 15     1999      12G  2020-03-18
# ...

# %%
sub = sub.drop(['Registered Number',"Registered Email ID"],axis=1)

# %%
sub.head()
# Out:
#    Child Name  Sale by Grade  Pricing Duration    Pay date
# 12   CH_31858  SP_1005     2      999    4G+1I  2020-03-18
# 15   CH_31860  SP_1005     4     1999      12G  2020-03-18
# 23   CH_31868  SP_1005     1     1999   10G+2I  2020-03-19
# 27   CH_31872  SP_1001     2     1999   10G+2I  2020-03-19
# 31   CH_31876  SP_1005     1      999    4G+1I  2020-03-20

# %% [markdown]
# ### Merging df_interested_users and df_subscription_bougth on Child Name column
# ### to know which child name was converted into a sale.

# %%
ndf=pd.merge(ndata,sub,on="Child Name",how="inner")

# %%
ndf.head()
# Out:
#   Child Name         phone                    email_id      source  \
# 0   CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
# 1   CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
# 2   CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
# 3   CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
# 4   CH_30004  911100221003  s2m_test_20004@tests2m.com  lastchance
#
#   Submitted date Enrolment Type                 School Attendance    Grade_x  \
# 0     2020-04-16          Trial  Bhartiya Vidya Bhavan    Present  Grade 1,2
# 1     2020-04-16          Trial  Bhartiya Vidya Bhavan    Present  Grade 1,2
# 2     2020-04-16          Trial  Bhartiya Vidya Bhavan    Present  Grade 1,2
# 3     2020-04-16          Trial  Bhartiya Vidya Bhavan    Present  Grade 1,2
# 4     2020-04-16          Trial  Bhartiya Vidya Bhavan    Present  Grade 1,2
#
#   Trainer Name  ...              Timing Batch size  Batch count     Batch  \
# ...

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5376 entries, 0 to 5375
# Data columns (total 21 columns):
# Child Name        5376 non-null object
# phone             5376 non-null int64
# email_id          5376 non-null object
# source            5376 non-null object
# Submitted date    5376 non-null object
# Enrolment Type    5376 non-null object
#  School           5376 non-null object
# Attendance        5292 non-null object
# Grade_x           5376 non-null object
# Trainer Name      5340 non-null object
# Date              5376 non-null object
# Timing            5376 non-null object
# Batch size        4781 non-null object
# Batch count       4781 non-null float64
# Batch             5376 non-null object
# Topics            5376 non-null object
# Sale by           5376 non-null object
# Grade_y           5232 non-null object
# Pricing           5376 non-null int64
# Duration          5244 non-null object
# Pay date          5376 non-null object
# ...

# %%
ndf["Pay date"].value_counts().head(5).plot(kind='bar',color="lightgreen")

# %%
ndf["source"].value_counts().head(5).plot(kind='bar',color="lightgreen")

# %%
ndf['Attendance'].replace({'Present ':'Present'},inplace=True)
ndf['Attendance']=ndf['Attendance'].fillna('Present')

# %%
ndf["Attendance"].value_counts().plot(kind='bar',color="lightgreen")

# %%
ndf["Pricing"].value_counts().plot(kind='bar',color="lightgreen")

# %%
ndf["Duration"].value_counts().head(5).plot(kind='bar',color="lightgreen")

# %%
ndf["Trainer Name"].value_counts().head(5).plot(kind='bar',color="lightgreen")

# %%
ndf["Timing"].value_counts().head(5).plot(kind='bar',color="lightgreen")

# %%
ndf["Batch"].value_counts().head(5).plot(kind='bar',color="lightgreen")

# %%
ndf["Sale by"].value_counts().head(5).plot(kind='bar',color="lightgreen")

# %%
ndf["Enrolment Type"].value_counts().head(5).plot(kind='bar',color="lightgreen")
